# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## PEDRO DOS SANTOS E SILVA
# ___

# %% [markdown]
# ## Quão díspare é a distribuição de informação no Brasil?

# %% [markdown]
# ___
# ## Introdução
#
# A minha análise pretende evidenciar a desigualdade na imersão social no mundo tecnológico dos dados, num mundo que, hoje, é capaz de mover o mundo da informação.
#
# Descreva aqui o que pretende analisar!
# --CRIAR VARIÁVEL RENDAS RELATIVAS
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados: Adicionar relatividade nas respostas como uma variável quantitativa

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import arange
import os

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Dell\Documents\2A\Dados\Projeto1

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
dados = pd.read_csv("PES2015.csv", sep=";")

# %%
dadosCut = dados.loc[:,["UF","V9532","V06111","V06112","V061113","V061114","V061115","V061116"]]

# %%
dados.UF = dados.UF.astype('category')
#dados.V9532 = dados.V9532.astype('category')
dados.V06111 = dados.V06111.astype('category')
dados.V06112 = dados.V06112.astype('category')
dados.V061113 = dados.V061113.astype('category')
dados.V061114 = dados.V061114.astype('category')
dados.V061115 = dados.V061115.astype('category')
dados.V061116 = dados.V061116.astype('category')

# %%
dadosCut.V06111.cat.categories = (['Sim','Não'])
dadosCut.V06112.cat.categories = (['Sim','Não'])
dadosCut.V061113.cat.categories = (['Sim','Não'])
dadosCut.V061114.cat.categories = (['Sim','Não'])
dadosCut.V061115.cat.categories = (['Sim','Não'])
dadosCut.V061116.cat.categories = (['Sim','Não'])

# %%
evc = dadosCut.V06111.value_counts().reindex(['Sim','Não'])

# %%
#evc.plot(kind='bar', color=('yellow', 'salmon', 'blue', 'red', 'green'),  legend=False)

# %%
ct_1112 = pd.crosstab(dadosCut.UF, dadosCut.V06111)

# %%
dadosCut.UF.cat.categories = (['Rondônia', 'Acre', 'Amazonas', 
                               'Roraima', 'Pará', 'Amapá', 
                               'Tocantins', 'Maranhão', 'Piauí', 
                               'Ceará','Rio Grande do Norte', 'Paraíba', 
                               'Pernambuco', 'Alagoas', 'Sergipe', 
                               'Bahia', 'Minas Gerais', 'Espírito Santo', 
                               'Rio de Janeiro', 'São Paulo', 'Paraná', 
                               'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul', 
                               'Mato Grosso', 'Goiás','Distrito Federal'])

# %%
ct_1314 = pd.crosstab(dadosCut.UF, dadosCut.V06112)

# %%
ct_1516 = pd.crosstab(dadosCut.UF, dadosCut.V061116)

# %%
ct_1112.plot(kind='bar', color=('yellow', 'salmon'))

# %%
ct_1314.plot(kind='bar', color=('yellow', 'salmon'))

# %%
ct_1516.plot(kind='bar')

# %%
#Criar relatividade na renda: --9532
cel2015 = dadosCut.V06112

# %%
ct=pd.crosstab(dadosCut.UF, dadosCut.V06111, margins=True, rownames=['ESTADO'], colnames=['Acessou em algum local'],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct[:-1].plot(kind='bar',stacked = True)
plt.ylabel('Frequência Relativa (em %)')
plt.grid(True)
#dadosCut.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
ct=pd.crosstab(dadosCut.UF, dadosCut.V06112, margins=True, rownames=['ESTADO'], colnames=['Acesso por meio de um microcomputador'],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct[:-1].plot(kind='bar',stacked = True)
plt.ylabel('Freq.Relativa (em %)')
#dadosCut.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador',
#'Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet 
#através de outro equipamento']

# %%
ct=pd.crosstab(dadosCut.UF, dadosCut.V06111, margins=True, rownames=['ESTADO'], colnames=['Acesso por meio de um celular'],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct[:-1].plot(kind='bar',stacked = True)
plt.ylabel('Freq.Relativa (em %)')
#dadosCut.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
ct=pd.crosstab(dadosCut.UF, dadosCut.V06111, margins=True, rownames=['ESTADO'], colnames=['Acesso por meio de um tablet '],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct[:-1].plot(kind='bar',stacked = True)
plt.ylabel('Freq.Relativa (em %)')
#dadosCut.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
ct=pd.crosstab(dadosCut.UF, dadosCut.V06111, margins=True, rownames=['ESTADO'], colnames=['Acesso pela TV'],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct[:-1].plot(kind='bar',stacked = True)
plt.ylabel('Freq.Relativa (em %)')
#dadosCut.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
ct=pd.crosstab(dadosCut.UF, dadosCut.V06111, margins=True, rownames=['ESTADO'], colnames=['Acesso por qualquer outro meio'],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct[:-1].plot(kind='bar',stacked = True)
plt.ylabel('Freq.Relativa (em %)')
#dadosCut.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %% [markdown]
# ___
# ## Conclusão

# %%
ct=pd.crosstab(dadosCut.UF, dadosCut.V06111,  rownames=['ESTADO'], colnames=['Acessou em algum local'],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct.plot(kind='bar',stacked = True)
plt.ylabel('Freq.Relativa (em %)')
