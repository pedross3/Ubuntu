# %%
import pandas as pd
import os
import numpy as np
print(os.getcwd())
#Quão díspare o Brasil é em termos de distribuição de informação?
#crosstab (quali com quali) cruza duas tabelas
#Tipos de variáveis: Quantitativas
                    #Qualitativas ordinais, e nominais
# Out:
# C:\Users\Dell\Documents\2A\Dados\CD17\Aula01_Tutorial

# %%
dados = pd.read_csv("PES2015.csv", sep=";")

# %%
dadosCut = dados.loc[:,["V8005","V06111","V06112","V061113","V061114","V061115","V061116"]]
pd.set_option('display.max_row', 20)
dadosCut.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dadosCut.loc[(dadosCut['Acessou internet em algum local'])== 1.0] =

# %%
dadosCut.dropna()
# Out:
#         Unidade da Federação  Acessou internet em algum local  \
# 0                         23                              1.0
# 1                         23                              1.0
# 2                         35                              1.0
# 3                         34                              1.0
# 4                         11                              1.0
# 7                         18                              1.0
# 10                        71                              1.0
# 12                        24                              1.0
# 16                        34                              1.0
# 17                        35                              1.0
# ...                      ...                              ...
# 356885                    32                              1.0
# 356886                    30                              1.0
# 356889                    34                              1.0
# ...

# %%
dadosCut.to_csv("problemáticos.csv")
